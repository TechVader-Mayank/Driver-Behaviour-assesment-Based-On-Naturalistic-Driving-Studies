# %%
import numpy as np

import pandas as pd

import matplotlib.pyplot as plt

# %matplotlib inline 

import seaborn as sns

from sklearn.cluster import KMeans
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('C:\\Users\\mayan\\OneDrive\\Desktop\\SPARK\\Driver Data\\combined_data_60.csv')
df=df.iloc[100001:120001]
df
# Out:
#         frame_no  Speed (km/h)  Heading (At Line) (Degrees)  \
# 100001   15142.0         87.24                        173.1
# 100002   15143.0         87.20                        173.1
# 100003   15144.0         86.99                        173.2
# 100004   15145.0         87.16                        173.1
# 100005   15146.0         87.37                        173.6
# ...          ...           ...                          ...
# 119996    2772.0         87.27                        154.6
# 119997    2773.0         87.09                        154.8
# 119998    2774.0         87.51                        154.8
# 119999    2775.0         87.02                        154.7
# 120000    2776.0         86.91                        154.5
#
#         Long Acc (At Line) (g)  Lat Acc (At Line) (g)  vehicle_density  \
# 100001                    0.06                  -0.03              0.0
# 100002                   -0.06                   0.02              0.0
# ...

# %%
df.shape
# Out:
# (20000, 67)

# %%
x = df['Long Acc (At Line) (g)']
max(x)
# Out:
# -1.19

# %%
# Assuming df is your DataFrame containing the data
column_name = 'Long Acc (At Line) (g)' # Replace 'column_name' with the actual column name

# Calculate the mean value of the column
mean_value = df[column_name].mean()


# Replace NaN values with the mean value
df[column_name].fillna(mean_value, inplace=True)



import pandas as pd

# Assuming df is your DataFrame containing the data
column_data = df['Long Acc (At Line) (g)']  # Replace 'column_name' with the actual column name

# Check for NaN values in the column
nan_values = column_data.isna().sum()

# Display the count of NaN values
print("Number of NaN values:", nan_values)
# Out:
# Number of NaN values: 0

# %%
import pandas as pd

# Assuming df is your DataFrame containing the data
column_name = 'Long Acc (At Line) (g)' # Replace 'column_name' with the actual column name

# Calculate the mean value of the column
mean_value = df[column_name].mean()


# Replace NaN values with the mean value
df[column_name].fillna(mean_value, inplace=True)



import pandas as pd

# Assuming df is your DataFrame containing the data
column_data = df['Long Acc (At Line) (g)']  # Replace 'column_name' with the actual column name

# Check for NaN values in the column
nan_values = column_data.isna().sum()

# Display the count of NaN values
print("Number of NaN values:", nan_values)
# Out:
# Number of NaN values: 0

# %%
df.shape
# Out:
# (20000, 67)

# %%
import pandas as pd

# Assuming df is your DataFrame containing the data
column_name = 'PEDAL_FORCE (At Line) (kg)' # Replace 'column_name' with the actual column name

# Calculate the mean value of the column
mean_value = df[column_name].mean()


# Replace NaN values with the mean value
df[column_name].fillna(mean_value, inplace=True)



import pandas as pd

# Assuming df is your DataFrame containing the data
column_data = df['PEDAL_FORCE (At Line) (kg)']  # Replace 'column_name' with the actual column name

# Check for NaN values in the column
nan_values = column_data.isna().sum()

# Display the count of NaN values
print("Number of NaN values:", nan_values)
# Out:
# Number of NaN values: 0

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans


X = df['PEDAL_FORCE (At Line) (kg)'].values.reshape(-1, 1)


k_values = range(1, 11)

inertia = []
for k in k_values:
    kmeans = KMeans(n_clusters=k)
    kmeans.fit(X)
    inertia.append(kmeans.inertia_)

plt.plot(k_values, inertia, marker='o')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Inertia')
plt.title('Elbow Curve')
plt.show()

# %%
import numpy as np
from sklearn.cluster import KMeans


X = df['PEDAL_FORCE (At Line) (kg)'].values.reshape(-1, 1)

k = 2

kmeans = KMeans(n_clusters=k)

kmeans.fit(X)

centers = kmeans.cluster_centers_

sorted_centers = np.sort(centers, axis=0)


threshold = (sorted_centers[0] + sorted_centers[1]) / 2

print("Threshold value:", threshold)

labels = kmeans.labels_

plt.scatter(X, labels)
plt.xlabel('PEDAL_FORCE (At Line) (kg)')
plt.ylabel('Cluster Label')
plt.title('K-Means Clustering')
plt.show()
# Out:
# Threshold value: [2.0082376]

# %%
df['y_pred_pedal_force'] = df['PEDAL_FORCE (At Line) (kg)'] > 2.81644434
df
# Out:
#       frame_no  Speed (km/h)  Heading (At Line) (Degrees)  \
# 0          0.0         92.13                        189.4
# 1          1.0         91.97                        189.4
# 2          2.0         91.79                        189.5
# 3          3.0         91.77                        189.2
# 4          4.0         92.38                        189.0
# ...        ...           ...                          ...
# 9995     765.0         58.84                        154.4
# 9996     766.0         59.44                        153.3
# 9997     767.0         58.38                        152.5
# 9998     768.0         59.60                        153.2
# 9999     769.0         60.41                        153.1
#
#       Long Acc (At Line) (g)  Lat Acc (At Line) (g)  vehicle_density  lane_id  \
# 0                       0.44                  -0.58              1.0        1
# 1                       0.24                  -0.15              1.0        1
# ...

# %%
#LONGITUDINAL ACCELERATION

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans


X = df['Long Acc (At Line) (g)'].values.reshape(-1, 1)

k_values = range(1, 11)


inertia = []
for k in k_values:
    kmeans = KMeans(n_clusters=k)
    kmeans.fit(X)
    inertia.append(kmeans.inertia_)


plt.plot(k_values, inertia, marker='o')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Inertia')
plt.title('Elbow Curve')
plt.show()

# %%
import numpy as np
from sklearn.cluster import KMeans


X = df['Long Acc (At Line) (g)'].values.reshape(-1, 1)

k = 4

kmeans = KMeans(n_clusters=k)

kmeans.fit(X)

centers = kmeans.cluster_centers_

sorted_centers = np.sort(centers, axis=0)


threshold1 = (sorted_centers[0] + sorted_centers[1]) / 2

print("Threshold value:", threshold1)

labels = kmeans.labels_

plt.scatter(X, labels)
plt.xlabel('Long Acc (At Line) (g)) (kg)')
plt.ylabel('Cluster Label')
plt.title('K-Means Clustering')
plt.show()
# Out:
# Threshold value: [-0.21490507]

# %%
df['y_pred_long_acc'] = df['Long Acc (At Line) (g)'] > -0.21490507
df
# Out:
#       frame_no  Speed (km/h)  Heading (At Line) (Degrees)  \
# 0          0.0         92.13                        189.4
# 1          1.0         91.97                        189.4
# 2          2.0         91.79                        189.5
# 3          3.0         91.77                        189.2
# 4          4.0         92.38                        189.0
# ...        ...           ...                          ...
# 9995     765.0         58.84                        154.4
# 9996     766.0         59.44                        153.3
# 9997     767.0         58.38                        152.5
# 9998     768.0         59.60                        153.2
# 9999     769.0         60.41                        153.1
#
#       Long Acc (At Line) (g)  Lat Acc (At Line) (g)  vehicle_density  lane_id  \
# 0                       0.44                  -0.58              1.0        1
# 1                       0.24                  -0.15              1.0        1
# ...

# %%
#JERK

# %%
df['Jerk']=None
time_diff = df['frame_no'].diff()

jerk = df['Long Acc (At Line) (g)'].diff() / time_diff

df['Jerk'] = jerk

# %%
jerk
# Out:
# 0        NaN
# 1      -0.20
# 2      -0.36
# 3      -0.08
# 4       0.82
#         ...
# 9995   -0.31
# 9996   -0.04
# 9997   -0.59
# 9998    0.69
# 9999    0.42
# Length: 10000, dtype: float64

# %%
import pandas as pd


column_name = 'Jerk' 

mean_value = df[column_name].mean()

df[column_name].fillna(mean_value, inplace=True)

import pandas as pd


column_data = df['Jerk']  


nan_values = column_data.isna().sum()


print("Number of NaN values:", nan_values)
# Out:
# Number of NaN values: 0

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans


X = df['Jerk'].values.reshape(-1, 1)

k_values = range(1, 11)


inertia = []
for k in k_values:
    kmeans = KMeans(n_clusters=k)
    kmeans.fit(X)
    inertia.append(kmeans.inertia_)


plt.plot(k_values, inertia, marker='o')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Inertia')
plt.title('Elbow Curve')
plt.show()

# %%
import numpy as np
from sklearn.cluster import KMeans


X = df['Jerk'].values.reshape(-1, 1)

k = 4

kmeans = KMeans(n_clusters=k)

kmeans.fit(X)

centers = kmeans.cluster_centers_

sorted_centers = np.sort(centers, axis=0)


threshold2 = (sorted_centers[0] + sorted_centers[1]) / 2

print("Threshold value:", threshold2)

labels = kmeans.labels_

plt.scatter(X, labels)
plt.xlabel('Jerk')
plt.ylabel('Cluster Label')
plt.title('K-Means Clustering')
plt.show()
# Out:
# Threshold value: [-0.29188116]

# %%
df['y_pred_jerk'] = df['Jerk'] > -0.29188116
df
# Out:
#       frame_no  Speed (km/h)  Heading (At Line) (Degrees)  \
# 0          0.0         92.13                        189.4
# 1          1.0         91.97                        189.4
# 2          2.0         91.79                        189.5
# 3          3.0         91.77                        189.2
# 4          4.0         92.38                        189.0
# ...        ...           ...                          ...
# 9995     765.0         58.84                        154.4
# 9996     766.0         59.44                        153.3
# 9997     767.0         58.38                        152.5
# 9998     768.0         59.60                        153.2
# 9999     769.0         60.41                        153.1
#
#       Long Acc (At Line) (g)  Lat Acc (At Line) (g)  vehicle_density  lane_id  \
# 0                       0.44                  -0.58              1.0        1
# 1                       0.24                  -0.15              1.0        1
# ...

# %%
#YAW RATE

# %%
import pandas as pd


column_name = 'yaw_rate' 

mean_value = df[column_name].mean()


df[column_name].fillna(mean_value, inplace=True)



import pandas as pd


column_data = df['yaw_rate'] 

nan_values = column_data.isna().sum()


print("Number of NaN values:", nan_values)
# Out:
# Number of NaN values: 0

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

X = df['yaw_rate'].values.reshape(-1, 1)

k_values = range(1, 11)

inertia = []
for k in k_values:
    kmeans = KMeans(n_clusters=k)
    kmeans.fit(X)
    inertia.append(kmeans.inertia_)

plt.plot(k_values, inertia, marker='o')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Inertia')
plt.title('Elbow Curve')
plt.show()

# %%
import numpy as np
from sklearn.cluster import KMeans


X = df['yaw_rate'].values.reshape(-1, 1)

k = 4

kmeans = KMeans(n_clusters=k)

kmeans.fit(X)

centers = kmeans.cluster_centers_

sorted_centers = np.sort(centers, axis=0)


threshold3 = (sorted_centers[0] + sorted_centers[1]) / 2

print("Threshold value:", threshold3)

labels = kmeans.labels_

plt.scatter(X, labels)
plt.xlabel('yaw_rate')
plt.ylabel('Cluster Label')
plt.title('K-Means Clustering')
plt.show()
# Out:
# Threshold value: [-2.63654896]

# %%
df['y_pred_yaw_rate'] = df['yaw_rate'] > -2.63654896
df
# Out:
#       frame_no  Speed (km/h)  Heading (At Line) (Degrees)  \
# 0          0.0         92.13                        189.4
# 1          1.0         91.97                        189.4
# 2          2.0         91.79                        189.5
# 3          3.0         91.77                        189.2
# 4          4.0         92.38                        189.0
# ...        ...           ...                          ...
# 9995     765.0         58.84                        154.4
# 9996     766.0         59.44                        153.3
# 9997     767.0         58.38                        152.5
# 9998     768.0         59.60                        153.2
# 9999     769.0         60.41                        153.1
#
#       Long Acc (At Line) (g)  Lat Acc (At Line) (g)  vehicle_density  lane_id  \
# 0                       0.44                  -0.58              1.0        1
# 1                       0.24                  -0.15              1.0        1
# ...

# %%
df.shape
# Out:
# (10000, 70)

# %%
true_values = df[df['y_pred_yaw_rate'] == True]

# %%
true_value=df[(df['C_lead_relative_speed'] < 0) & (df['C_leader_available_in_curr'] == 1)]
true_value
# Out:
#       frame_no  Speed (km/h)  Heading (At Line) (Degrees)  \
# 898      898.0         96.51                        181.6
# 899      899.0         95.97                        181.6
# 900      900.0         95.94                        181.4
# 901      901.0         96.32                        181.2
# 902      902.0         96.41                        181.2
# ...        ...           ...                          ...
# 9822     592.0         96.24                        153.2
# 9823     593.0         96.65                        153.1
# 9824     594.0         96.43                        153.1
# 9825     595.0         96.44                        153.3
# 9826     596.0         96.38                        153.1
#
#       Long Acc (At Line) (g)  Lat Acc (At Line) (g)  vehicle_density  lane_id  \
# 898                    -0.09                   0.13              2.0        1
# 899                     0.00                  -0.06              2.0        1
# ...

# %%
import pandas as pd

condition1 = df['C_lead_relative_speed'] < 0  
condition2 = df['C_leader_available_in_curr'] == 1  
condition3 = df['C_lead_long_gap'] > 0 

combined_condition = condition1 & condition2 & condition3

df.loc[combined_condition, 'TTC'] = df.loc[combined_condition, 'C_lead_long_gap'] / df.loc[combined_condition, 'C_lead_relative_speed']

non_empty_rows = df.loc[df['TTC'].notnull()]

non_empty_rows.to_csv(r'C:\Users\mayan\OneDrive\Desktop\SPARK\data.csv', index=False)

# %%
mask = df[['y_pred_jerk', 'y_pred_yaw_rate', 'y_pred_pedal_force', 'y_pred_long_acc']].all(axis=1)

not_null_mask = df['TTC'].notnull()

combined_mask = mask & not_null_mask
filtered_df = df[combined_mask]
print(filtered_df)
filtered_df.to_csv(r'C:\Users\mayan\OneDrive\Desktop\SPARK\data.csv', index=False)
# Out:
#       frame_no  Speed (km/h)  Heading (At Line) (Degrees)  \
# 1723    1723.0         97.66                        149.8
# 1727    1727.0         96.38                        149.9
# 1729    1729.0         95.18                        149.4
# 1730    1730.0         94.91                        149.4
# 1732    1732.0         94.75                        149.3
# 1734    1734.0         93.90                        149.2
# 1739    1739.0         91.71                        149.3
# 1741    1741.0         90.36                        148.8
# 7673    7673.0        113.70                        149.3
# 7674    7674.0        113.50                        149.2
# 7676    7676.0        112.96                        149.2
# 7680    7680.0        111.69                        149.1
# 7681    7681.0        111.72                        148.9
# 7683    7683.0        111.27                        149.1
# 7684    7684.0        110.45                        149.0
# ...
